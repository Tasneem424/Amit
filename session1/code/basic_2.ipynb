# %%
list_one=['depi','learning','ml']
list_one.append('deeplearning')
list_one
# Out:
# ['depi', 'learning', 'ml', 'deeplearning']

# %%
list_one.insert(0,'data')
list_one
# Out:
# ['data', 'depi', 'learning', 'ml', 'deeplearning']

# %%
list_one.remove('depi')

# %%
x=list_one.pop(0)
x
# Out:
# 'data'

# %%
list_1=[1,2,3]
list_2=[4,5,6]
list_3=[7,8,9]
matrix=[list_1,list_2,list_3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
list_1*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
name=input("enter your name")
id=input("enter your id")
print(f"my name is {name},my ID is {id}")
# Out:
# my name is tasneem,my ID is 20223385

# %%
input_lst=['amit','learning','ml','datasciece','dp']
str=input("pls enter a string")
input_lst.remove(str)
input_lst
# Out:
# ['amit', 'learning', 'datasciece', 'dp']

# %%
lst_sort=[1,5,6,3,2,4,0]
lst_sort.sort()
lst_sort
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
n='depi'
tuple(n)
# Out:
# ('d', 'e', 'p', 'i')

# %%
set1={"depi","learning","ml"}
set1
# Out:
# {'depi', 'learning', 'ml'}

# %%
set1.discard("ml")
set1
# Out:
# {'depi', 'learning'}

# %%
dect1={"key1":25}
dect1["key1"]="depi"
dect1
# Out:
# {'key1': 'depi'}

# %%
num1=float(input("enter fist num"))
num2=float(input("enter fist num"))
print(f"Sum = {num1+num2}")
print(f"sub = {num1-num2}")
print(f"mult = {num1*num2}")
print(f"div = {num1/num2}")
# Out:
# Sum = 15.0
# sub = 5.0
# mult = 50.0
# div = 2.0

# %%
x=5
y=10
if x > 0 and y > 0 :
     print("positive numbers")
# Out:
# positive numbers

# %%
x=5
result= "Even" if x % 2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
a=10
b=5
result= a + b if a > b else a - b 
result
# Out:
# 15

# %%
is_sunny=True
tem=25

if is_sunny:
     print("sunny day")
     if tem>20:
          print("warm")
     else:
          print("cool")
else :
     print("cloudy day")
# Out:
# sunny day
# warm

# %%
grade = int (input("enter your grade :"))

if 0 <= grade <= 100:
     if 85 <= grade <=100:
          grade = "A"
     elif 65 <= grade <=85:
          grade = "B"
     elif 45 <= grade <= 65:
          grade="D"
     else :
          grade="F"


print(grade)
# Out:
# D
