# %%
name ="depi"
age=30
print("my name is {0} my age is {1}".format(name,age))
# Out:
# my name is depi my age is 30

# %%
print(f"my name is {name} my age is {age}")
# Out:
# my name is depi my age is 30

# %%
name="tasneem"
age=22
course="ml"
print("my name is {0} my age is {1} my course is {2}".format(name,age,course))
# Out:
# my name is tasneem my age is 22 my course is ml

# %%
name="depi learning"
upper_txt=name.upper()
upper_txt
# Out:
# 'DEPI LEARNING'

# %%
upper_txt.lower()
# Out:
# 'depi learning'

# %%
name.replace("depi","depi_ml")
# Out:
# 'depi_ml learning'

# %%
name="depi learning for machine learning depi"
# name.count("depi")
print(type(name))
x=name.split()
print(type(x))
# Out:
# <class 'str'>
# <class 'list'>

# %%
response=' '.join(x)
type(response)
# Out:
# str

# %%
name="depi learning for \"machine learning\" depi"
name
# Out:
# 'depi learning for "machine learning" depi'

# %%
x=[2,"python",10]
x[1]
# Out:
# 'python'
